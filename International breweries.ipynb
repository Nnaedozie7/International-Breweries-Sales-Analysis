# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\Owner\Documents\techtern datas\International_Breweries (1).csv")

# %%
df
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0        10101   Jardine       jard@gmail.com       trophy         150
# 1        10102      Gill      gillhell@uk.com    budweiser         250
# 2        10103   Sorvino  sorvi2000@gmail.com  castle lite         180
# 3        10104     Jones    jone.ai@yahoo.com  eagle lager         170
# 4        10105   Andrews       andy@gmail.com         hero         150
# ...        ...       ...                  ...          ...         ...
# 1042     11143   Jardine       jard@gmail.com   grand malt          90
# 1043     11144   Jardine       jard@gmail.com       trophy         150
# 1044     11145   Andrews       andy@gmail.com    budweiser         250
# 1045     11146     Jones    jone.ai@yahoo.com  castle lite         180
# 1046     11147    Morgan   morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION     MONTHS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047 entries, 0 to 1046
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SALES_ID    1047 non-null   int64
#  1   SALES_REP   1047 non-null   object
#  2   EMAILS      1047 non-null   object
#  3   BRANDS      1047 non-null   object
#  4   PLANT_COST  1047 non-null   int64
#  5   UNIT_PRICE  1047 non-null   int64
#  6   QUANTITY    1047 non-null   int64
#  7   COST        1047 non-null   int64
#  8   PROFIT      1047 non-null   int64
#  9   COUNTRIES   1047 non-null   object
#  10  REGION      1047 non-null   object
#  11  MONTHS      1047 non-null   object
#  12  YEARS       1047 non-null   int64
# dtypes: int64(7), object(6)
# memory usage: 106.5+ KB

# %%
list(df.SALES_REP.unique())
# Out:
# ['Jardine',
#  'Gill',
#  'Sorvino',
#  'Jones',
#  'Andrews',
#  'Thompson',
#  'Morgan',
#  'Howard',
#  'Parent',
#  'Smith',
#  'Kivell']

# %%
df.SALES_REP.values
# Out:
# array(['Jardine', 'Gill', 'Sorvino', ..., 'Andrews', 'Jones', 'Morgan'],
#       dtype=object)

# %%
df.BRANDS.unique()
# Out:
# array(['trophy', 'budweiser', 'castle lite', 'eagle lager', 'hero',
#        'beta malt', 'grand malt'], dtype=object)

# %%
df.COUNTRIES.unique()
# Out:
# array(['Ghana', 'Nigeria', 'Togo', 'Benin', 'Senegal'], dtype=object)

# %%
max(df.QUANTITY)
# Out:
# 1000

# %%
df.loc[df.QUANTITY == max(df.QUANTITY)]
# Out:
#      SALES_ID SALES_REP              EMAILS  BRANDS  PLANT_COST  UNIT_PRICE  \
# 32      10133    Kivell  kivel_go@yahoo.com    hero         150         200
# 186     10287   Jardine      jard@gmail.com    hero         150         200
# 798     10899    Morgan  morganny@gmail.com  trophy         150         200
#
#      QUANTITY    COST  PROFIT COUNTRIES     REGION      MONTHS  YEARS
# 32       1000  200000   50000      Togo  southsouth  September   2019
# 186      1000  200000   50000   Nigeria   Southeast       July   2017
# 798      1000  200000   50000     Benin   Southeast       July   2018

# %%
min(df.QUANTITY)
# Out:
# 700

# %%
df.loc[df.QUANTITY == min(df.QUANTITY)]
# Out:
#       SALES_ID SALES_REP                    EMAILS       BRANDS  PLANT_COST  \
# 8        10109    Morgan        morganny@gmail.com    budweiser         250
# 371      10472    Howard  howard_freeman@yahoo.com       trophy         150
# 661      10762    Parent           parentty@uk.com  eagle lager         170
# 1030     11131    Howard  howard_freeman@yahoo.com    budweiser         250
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION   \
# 8            500       700  350000  175000     Benin     southsouth
# 371          200       700  140000   35000   Nigeria  northcentral
# 661          250       700  175000   56000   Nigeria           west
# 1030         500       700  350000  175000     Ghana     northeast
#
#          MONTHS  YEARS
# 8     September   2019
# 371    December   2017
# 661    February   2019
# 1030   November   2019

# %%
max(df.UNIT_PRICE)
# Out:
# 500

# %%
df.loc[df.UNIT_PRICE == max(df.UNIT_PRICE)]
# Out:
#       SALES_ID SALES_REP                    EMAILS     BRANDS  PLANT_COST  \
# 1        10102      Gill           gillhell@uk.com  budweiser         250
# 8        10109    Morgan        morganny@gmail.com  budweiser         250
# 15       10116     Jones         jone.ai@yahoo.com  budweiser         250
# 22       10123     Jones         jone.ai@yahoo.com  budweiser         250
# 29       10130    Kivell        kivel_go@yahoo.com  budweiser         250
# ...        ...       ...                       ...        ...         ...
# 1016     11117     Smith        smithMan@yahoo.com  budweiser         250
# 1023     11124    Parent           parentty@uk.com  budweiser         250
# 1030     11131    Howard  howard_freeman@yahoo.com  budweiser         250
# 1037     11138   Sorvino       sorvi2000@gmail.com  budweiser         250
# 1044     11145   Andrews            andy@gmail.com  budweiser         250
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION   \
# ...

# %%
min(df.UNIT_PRICE)
# Out:
# 150

# %%
df.loc[df.UNIT_PRICE == min(df.UNIT_PRICE)]
# Out:
#       SALES_ID SALES_REP              EMAILS      BRANDS  PLANT_COST  \
# 5        10106   Jardine      jard@gmail.com   beta malt          80
# 6        10107  Thompson        thomp@uk.com  grand malt          90
# 12       10113     Smith  smithMan@yahoo.com   beta malt          80
# 13       10114     Jones   jone.ai@yahoo.com  grand malt          90
# 19       10120    Parent     parentty@uk.com   beta malt          80
# ...        ...       ...                 ...         ...         ...
# 1028     11129   Jardine      jard@gmail.com  grand malt          90
# 1034     11135     Jones   jone.ai@yahoo.com   beta malt          80
# 1035     11136    Morgan  morganny@gmail.com  grand malt          90
# 1041     11142   Andrews      andy@gmail.com   beta malt          80
# 1042     11143   Jardine      jard@gmail.com  grand malt          90
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION   \
# 5            150       798  119700   55860     Ghana  northcentral
# ...

# %%
max(df.PROFIT)
# Out:
# 269190

# %%
df.loc[df.PROFIT == max(df.PROFIT)]
# Out:
#      SALES_ID SALES_REP                    EMAILS       BRANDS  PLANT_COST  \
# 310     10411     Jones         jone.ai@yahoo.com  castle lite         180
# 709     10810    Howard  howard_freeman@yahoo.com  castle lite         180
#
#      UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES     REGION     MONTHS  \
# 310         450       997  448650  269190     Ghana  northeast   November
# 709         450       997  448650  269190   Senegal        west  February
#
#      YEARS
# 310   2019
# 709   2019

# %%
min(df.PROFIT)
# Out:
# 35000

# %%
df.loc[df.PROFIT == min(df.PROFIT)]
# Out:
#      SALES_ID SALES_REP                    EMAILS  BRANDS  PLANT_COST  \
# 371     10472    Howard  howard_freeman@yahoo.com  trophy         150
#
#      UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION     MONTHS  \
# 371         200       700  140000   35000   Nigeria  northcentral   December
#
#      YEARS
# 371   2017

# %%
df.values
# Out:
# array([[10101, 'Jardine', 'jard@gmail.com', ..., 'Southeast', 'January',
#         2019],
#        [10102, 'Gill', 'gillhell@uk.com', ..., 'west', 'February', 2018],
#        [10103, 'Sorvino', 'sorvi2000@gmail.com', ..., 'southsouth',
#         'March', 2018],
#        ...,
#        [11145, 'Andrews', 'andy@gmail.com', ..., 'Southeast', 'January',
#         2019],
#        [11146, 'Jones', 'jone.ai@yahoo.com', ..., 'west', 'February',
#         2017],
#        [11147, 'Morgan', 'morganny@gmail.com', ..., 'southsouth',
#         'March', 2019]], dtype=object)

# %%
df2017 = df.loc[df.YEARS == 2017]

# %%
df2017
# Out:
#       SALES_ID SALES_REP                    EMAILS       BRANDS  PLANT_COST  \
# 4        10105   Andrews            andy@gmail.com         hero         150
# 6        10107  Thompson              thomp@uk.com   grand malt          90
# 9        10110    Howard  howard_freeman@yahoo.com  castle lite         180
# 10       10111    Parent           parentty@uk.com  eagle lager         170
# 13       10114     Jones         jone.ai@yahoo.com   grand malt          90
# ...        ...       ...                       ...          ...         ...
# 1038     11139      Gill           gillhell@uk.com  castle lite         180
# 1039     11140   Sorvino       sorvi2000@gmail.com  eagle lager         170
# 1042     11143   Jardine            jard@gmail.com   grand malt          90
# 1043     11144   Jardine            jard@gmail.com       trophy         150
# 1045     11146     Jones         jone.ai@yahoo.com  castle lite         180
#
# ...

# %%
max(df2017.QUANTITY)
# Out:
# 1000

# %%
df2017.loc[df.QUANTITY == max(df.QUANTITY)]
# Out:
#      SALES_ID SALES_REP          EMAILS BRANDS  PLANT_COST  UNIT_PRICE  \
# 186     10287   Jardine  jard@gmail.com   hero         150         200
#
#      QUANTITY    COST  PROFIT COUNTRIES    REGION  MONTHS  YEARS
# 186      1000  200000   50000   Nigeria  Southeast   July   2017

# %%
min(df2017.QUANTITY)
# Out:
# 700

# %%
df2017.loc[df.QUANTITY == min(df.QUANTITY)]
# Out:
#      SALES_ID SALES_REP                    EMAILS  BRANDS  PLANT_COST  \
# 371     10472    Howard  howard_freeman@yahoo.com  trophy         150
#
#      UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION     MONTHS  \
# 371         200       700  140000   35000   Nigeria  northcentral   December
#
#      YEARS
# 371   2017

# %%
df2017.loc[df2017.PROFIT == max(df2017.PROFIT)]
# Out:
#      SALES_ID SALES_REP              EMAILS       BRANDS  PLANT_COST  \
# 618     10719    Morgan  morganny@gmail.com  castle lite         180
#
#      UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES    REGION  MONTHS  YEARS
# 618         450       995  447750  268650     Benin  Southeast   July   2017

# %%
df2017.loc[df2017.PROFIT == min(df2017.PROFIT)]
# Out:
#      SALES_ID SALES_REP                    EMAILS  BRANDS  PLANT_COST  \
# 371     10472    Howard  howard_freeman@yahoo.com  trophy         150
#
#      UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION     MONTHS  \
# 371         200       700  140000   35000   Nigeria  northcentral   December
#
#      YEARS
# 371   2017

# %%
df2017.loc[df2017.COST == max(df2017.COST)]
# Out:
#      SALES_ID SALES_REP             EMAILS     BRANDS  PLANT_COST  UNIT_PRICE  \
# 302     10403  Thompson       thomp@uk.com  budweiser         250         500
# 589     10690     Jones  jone.ai@yahoo.com  budweiser         250         500
# 841     10942   Andrews     andy@gmail.com  budweiser         250         500
#
#      QUANTITY    COST  PROFIT COUNTRIES     REGION     MONTHS  YEARS
# 302       998  499000  249500      Togo  southsouth     March   2017
# 589       998  499000  249500   Senegal        west  February   2017
# 841       998  499000  249500   Nigeria        west  February   2017

# %%
df2017.loc[df2017.COST == min(df2017.COST)]
# Out:
#      SALES_ID SALES_REP              EMAILS      BRANDS  PLANT_COST  \
# 552     10653    Kivell  kivel_go@yahoo.com  grand malt          90
#
#      UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES    REGION    MONTHS  YEARS
# 552         150       702  105300   42120      Togo  Southeast  January   2017

# %%
df2017.loc[df2017.UNIT_PRICE == min(df2017.UNIT_PRICE)]
# Out:
#       SALES_ID SALES_REP                    EMAILS      BRANDS  PLANT_COST  \
# 6        10107  Thompson              thomp@uk.com  grand malt          90
# 13       10114     Jones         jone.ai@yahoo.com  grand malt          90
# 19       10120    Parent           parentty@uk.com   beta malt          80
# 20       10121      Gill           gillhell@uk.com  grand malt          90
# 26       10127    Howard  howard_freeman@yahoo.com   beta malt          80
# ...        ...       ...                       ...         ...         ...
# 1006     11107   Sorvino       sorvi2000@gmail.com   beta malt          80
# 1013     11114    Howard  howard_freeman@yahoo.com   beta malt          80
# 1020     11121    Parent           parentty@uk.com   beta malt          80
# 1027     11128   Sorvino       sorvi2000@gmail.com   beta malt          80
# 1042     11143   Jardine            jard@gmail.com  grand malt          90
#
# ...

# %%
df2017.loc[df2017.UNIT_PRICE == min(df2017.UNIT_PRICE)]
# Out:
#       SALES_ID SALES_REP                    EMAILS      BRANDS  PLANT_COST  \
# 6        10107  Thompson              thomp@uk.com  grand malt          90
# 13       10114     Jones         jone.ai@yahoo.com  grand malt          90
# 19       10120    Parent           parentty@uk.com   beta malt          80
# 20       10121      Gill           gillhell@uk.com  grand malt          90
# 26       10127    Howard  howard_freeman@yahoo.com   beta malt          80
# ...        ...       ...                       ...         ...         ...
# 1006     11107   Sorvino       sorvi2000@gmail.com   beta malt          80
# 1013     11114    Howard  howard_freeman@yahoo.com   beta malt          80
# 1020     11121    Parent           parentty@uk.com   beta malt          80
# 1027     11128   Sorvino       sorvi2000@gmail.com   beta malt          80
# 1042     11143   Jardine            jard@gmail.com  grand malt          90
#
# ...

# %%
df2018 = df.loc[df.YEARS == 2018]

# %%
df2018
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 1        10102      Gill      gillhell@uk.com    budweiser         250
# 2        10103   Sorvino  sorvi2000@gmail.com  castle lite         180
# 3        10104     Jones    jone.ai@yahoo.com  eagle lager         170
# 7        10108     Jones    jone.ai@yahoo.com       trophy         150
# 12       10113     Smith   smithMan@yahoo.com    beta malt          80
# ...        ...       ...                  ...          ...         ...
# 1023     11124    Parent      parentty@uk.com    budweiser         250
# 1026     11127     Jones    jone.ai@yahoo.com         hero         150
# 1031     11132      Gill      gillhell@uk.com  castle lite         180
# 1033     11134    Kivell   kivel_go@yahoo.com         hero         150
# 1041     11142   Andrews       andy@gmail.com    beta malt          80
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION     MONTHS  \
# ...

# %%
max(df2018.QUANTITY)
# Out:
# 1000

# %%
df2018.loc[df.QUANTITY == max(df2018.QUANTITY)]
# Out:
#      SALES_ID SALES_REP              EMAILS  BRANDS  PLANT_COST  UNIT_PRICE  \
# 798     10899    Morgan  morganny@gmail.com  trophy         150         200
#
#      QUANTITY    COST  PROFIT COUNTRIES    REGION  MONTHS  YEARS
# 798      1000  200000   50000     Benin  Southeast   July   2018

# %%
df2018.loc[df.QUANTITY == min(df2018.QUANTITY)]
# Out:
#      SALES_ID SALES_REP          EMAILS       BRANDS  PLANT_COST  UNIT_PRICE  \
# 80      10181   Jardine  jard@gmail.com  eagle lager         170         250
# 897     10998   Jardine  jard@gmail.com    budweiser         250         500
#
#      QUANTITY    COST  PROFIT COUNTRIES     REGION      MONTHS  YEARS
# 80        701  175250   56080     Ghana  southsouth  September   2018
# 897       701  350500  175250      Togo   northwest    October   2018

# %%
df2018.loc[df2018.PROFIT == max(df2018.PROFIT)]
# Out:
#      SALES_ID SALES_REP          EMAILS       BRANDS  PLANT_COST  UNIT_PRICE  \
# 814     10915   Jardine  jard@gmail.com  castle lite         180         450
#
#      QUANTITY    COST  PROFIT COUNTRIES     REGION     MONTHS  YEARS
# 814       992  446400  267840   Senegal  northeast   November   2018

# %%
df2018.loc[df2018.PROFIT == min(df2018.PROFIT)]
# Out:
#      SALES_ID SALES_REP        EMAILS  BRANDS  PLANT_COST  UNIT_PRICE  \
# 903     11004  Thompson  thomp@uk.com  trophy         150         200
#
#      QUANTITY    COST  PROFIT COUNTRIES    REGION  MONTHS  YEARS
# 903       702  140400   35100     Benin  northwest  April   2018

# %%
df2019 = df.loc[df.YEARS == 2019]

# %%
df2019
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0        10101   Jardine       jard@gmail.com       trophy         150
# 5        10106   Jardine       jard@gmail.com    beta malt          80
# 8        10109    Morgan   morganny@gmail.com    budweiser         250
# 11       10112     Jones    jone.ai@yahoo.com         hero         150
# 15       10116     Jones    jone.ai@yahoo.com    budweiser         250
# ...        ...       ...                  ...          ...         ...
# 1035     11136    Morgan   morganny@gmail.com   grand malt          90
# 1037     11138   Sorvino  sorvi2000@gmail.com    budweiser         250
# 1040     11141  Thompson         thomp@uk.com         hero         150
# 1044     11145   Andrews       andy@gmail.com    budweiser         250
# 1046     11147    Morgan   morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION   \
# ...

# %%
df2019.loc[df2019.QUANTITY == max(df2019.QUANTITY)]
# Out:
#     SALES_ID SALES_REP              EMAILS BRANDS  PLANT_COST  UNIT_PRICE  \
# 32     10133    Kivell  kivel_go@yahoo.com   hero         150         200
#
#     QUANTITY    COST  PROFIT COUNTRIES     REGION      MONTHS  YEARS
# 32      1000  200000   50000      Togo  southsouth  September   2019

# %%
df2019.loc[df2019.QUANTITY == min(df2019.QUANTITY)]
# Out:
#       SALES_ID SALES_REP                    EMAILS       BRANDS  PLANT_COST  \
# 8        10109    Morgan        morganny@gmail.com    budweiser         250
# 661      10762    Parent           parentty@uk.com  eagle lager         170
# 1030     11131    Howard  howard_freeman@yahoo.com    budweiser         250
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES     REGION      MONTHS  \
# 8            500       700  350000  175000     Benin  southsouth  September
# 661          250       700  175000   56000   Nigeria        west   February
# 1030         500       700  350000  175000     Ghana  northeast    November
#
#       YEARS
# 8      2019
# 661    2019
# 1030   2019

# %%
df2019.loc[df2019.PROFIT == max(df2019.PROFIT)]
# Out:
#      SALES_ID SALES_REP                    EMAILS       BRANDS  PLANT_COST  \
# 310     10411     Jones         jone.ai@yahoo.com  castle lite         180
# 709     10810    Howard  howard_freeman@yahoo.com  castle lite         180
#
#      UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES     REGION     MONTHS  \
# 310         450       997  448650  269190     Ghana  northeast   November
# 709         450       997  448650  269190   Senegal        west  February
#
#      YEARS
# 310   2019
# 709   2019

# %%
df2019.loc[df2019.PROFIT == min(df2019.PROFIT)]
# Out:
#      SALES_ID SALES_REP          EMAILS  BRANDS  PLANT_COST  UNIT_PRICE  \
# 259     10360   Andrews  andy@gmail.com  trophy         150         200
#
#      QUANTITY    COST  PROFIT COUNTRIES REGION   MONTHS  YEARS
# 259       704  140800   35200   Senegal    west  August   2019

# %%
malt = ['beta malt','grand malt' ]
maltDF = df[df['BRANDS'].isin(malt)]

# %%
maltDF
# Out:
#       SALES_ID SALES_REP              EMAILS      BRANDS  PLANT_COST  \
# 5        10106   Jardine      jard@gmail.com   beta malt          80
# 6        10107  Thompson        thomp@uk.com  grand malt          90
# 12       10113     Smith  smithMan@yahoo.com   beta malt          80
# 13       10114     Jones   jone.ai@yahoo.com  grand malt          90
# 19       10120    Parent     parentty@uk.com   beta malt          80
# ...        ...       ...                 ...         ...         ...
# 1028     11129   Jardine      jard@gmail.com  grand malt          90
# 1034     11135     Jones   jone.ai@yahoo.com   beta malt          80
# 1035     11136    Morgan  morganny@gmail.com  grand malt          90
# 1041     11142   Andrews      andy@gmail.com   beta malt          80
# 1042     11143   Jardine      jard@gmail.com  grand malt          90
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION   \
# 5            150       798  119700   55860     Ghana  northcentral
# ...

# %%
maltDF.loc[maltDF.QUANTITY == max(maltDF.QUANTITY)]
# Out:
#      SALES_ID SALES_REP           EMAILS     BRANDS  PLANT_COST  UNIT_PRICE  \
# 817     10918      Gill  gillhell@uk.com  beta malt          80         150
#
#      QUANTITY    COST  PROFIT COUNTRIES REGION     MONTHS  YEARS
# 817       997  149550   69790      Togo    west  February   2017

# %%
maltDF.loc[maltDF.PROFIT == max(maltDF.PROFIT)]
# Out:
#      SALES_ID SALES_REP           EMAILS     BRANDS  PLANT_COST  UNIT_PRICE  \
# 817     10918      Gill  gillhell@uk.com  beta malt          80         150
#
#      QUANTITY    COST  PROFIT COUNTRIES REGION     MONTHS  YEARS
# 817       997  149550   69790      Togo    west  February   2017

# %%
beer = ['trophy', 'budweiser', 'castle lite', 'eagle lager', 'hero', ]
beerDF = df[df['BRANDS'].isin(beer)]

# %%
beerDF
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0        10101   Jardine       jard@gmail.com       trophy         150
# 1        10102      Gill      gillhell@uk.com    budweiser         250
# 2        10103   Sorvino  sorvi2000@gmail.com  castle lite         180
# 3        10104     Jones    jone.ai@yahoo.com  eagle lager         170
# 4        10105   Andrews       andy@gmail.com         hero         150
# ...        ...       ...                  ...          ...         ...
# 1040     11141  Thompson         thomp@uk.com         hero         150
# 1043     11144   Jardine       jard@gmail.com       trophy         150
# 1044     11145   Andrews       andy@gmail.com    budweiser         250
# 1045     11146     Jones    jone.ai@yahoo.com  castle lite         180
# 1046     11147    Morgan   morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION   \
# ...

# %%
beerDF.loc[beerDF.QUANTITY == max(beerDF.QUANTITY)]
# Out:
#      SALES_ID SALES_REP              EMAILS  BRANDS  PLANT_COST  UNIT_PRICE  \
# 32      10133    Kivell  kivel_go@yahoo.com    hero         150         200
# 186     10287   Jardine      jard@gmail.com    hero         150         200
# 798     10899    Morgan  morganny@gmail.com  trophy         150         200
#
#      QUANTITY    COST  PROFIT COUNTRIES     REGION      MONTHS  YEARS
# 32       1000  200000   50000      Togo  southsouth  September   2019
# 186      1000  200000   50000   Nigeria   Southeast       July   2017
# 798      1000  200000   50000     Benin   Southeast       July   2018

# %%
beerDF.loc[beerDF.PROFIT == max(beerDF.PROFIT)]
# Out:
#      SALES_ID SALES_REP                    EMAILS       BRANDS  PLANT_COST  \
# 310     10411     Jones         jone.ai@yahoo.com  castle lite         180
# 709     10810    Howard  howard_freeman@yahoo.com  castle lite         180
#
#      UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES     REGION     MONTHS  \
# 310         450       997  448650  269190     Ghana  northeast   November
# 709         450       997  448650  269190   Senegal        west  February
#
#      YEARS
# 310   2019
# 709   2019

# %%
sns.barplot(x='BRANDS', y='PROFIT', data=beerDF)
# Out:
# <AxesSubplot:xlabel='BRANDS', ylabel='PROFIT'>

# %%
sns.barplot(x='BRANDS', y='PROFIT', data=maltDF)
# Out:
# <AxesSubplot:xlabel='BRANDS', ylabel='PROFIT'>

# %%
sns.barplot(x='BRANDS', y='QUANTITY', data=maltDF)
# Out:
# <AxesSubplot:xlabel='BRANDS', ylabel='QUANTITY'>

# %%
sns.barplot(x='BRANDS', y='PROFIT', data=df)
# Out:
# <AxesSubplot:xlabel='BRANDS', ylabel='PROFIT'>

# %%
sns.barplot(x='BRANDS', y='QUANTITY', data=df)
# Out:
# <AxesSubplot:xlabel='BRANDS', ylabel='QUANTITY'>
